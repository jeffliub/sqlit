# %%
import jfutils.dbutils
import streamlit as st

# %%
db='postgres'
sc=jfutils.dbutils.DBUtils(db,st.secrets[db]['server'],st.secrets[db]['port'],st.secrets[db]['user'],st.secrets[db]['password'],st.secrets[db]['database'])
data=sc.get_query_rows('select * from tcommodity limit 10')

# %%
data
# Out:
# [(2,
#   'Premium Roller Frame',
#   None,
#   '230mm',
#   None,
#   None,
#   'https://garageworkshop.co.nz/products/premium-roller-frame?_kx=kaU9N5EtXDQbhzGjmW7cP8wY5s1TH-Prc6qdFst1UDo%3D.WpEj7E',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   12.76,
#   'NZD',
#   datetime.date(2023, 4, 17),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 16, 41, 20, 501644),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 16, 41, 20, 501644)),
#  (8,
#   '洗车液水蜡高泡强力去污PA预洗液泡沫清洗剂汽车专用',
#   '绿田（LUTIAN）',
#   '飞雪483ml ',
#   None,
#   None,
#   'https://item.jd.com/100016468197.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   40.0,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 35, 54, 735780),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 35, 54, 735780)),
#  (15,
#   '补鞋胶鞋胶修鞋匠粘鞋胶运动鞋皮鞋树脂软性防水强力修鞋胶水 ',
#   '际工',
#   None,
#   None,
#   None,
#   'https://item.jd.com/10022625641654.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   11.6,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 45, 24, 700337),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 45, 24, 700337)),
#  (17,
#   '密码挂锁',
#   '际工',
#   '80mm 4bit',
#   None,
#   None,
#   'https://item.jd.com/10040369607100.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   12.2,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 45, 24, 700337),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 45, 24, 700337)),
#  (21,
#   '跳绳成人计数无绳有绳款加粗学校中考考试训练负重两用健身器材体育室内外运动跳绳儿童小学生',
#   '特步（XTEP）',
#   '加长280CM绳体',
#   None,
#   None,
#   'https://item.jd.com/100014745199.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Amy',
#   'bought',
#   26.1,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 56, 34, 57054),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 56, 34, 57054)),
#  (5,
#   '水管挂钩滑板承重墙壁重物收纳免打孔挂勾展示架头盔挂钩',
#   '恒愎',
#   '中方钩【橙色】 含免钉胶+螺丝',
#   None,
#   None,
#   'https://item.jd.com/10066851977335.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   19.2,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '成本含摊薄3元运费',
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 771854),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 771854)),
#  (6,
#   '水管挂钩滑板承重墙壁重物收纳免打孔挂勾展示架头盔挂钩',
#   '恒愎',
#   '拖把钩【橙色】 含免钉胶+螺丝',
#   None,
#   None,
#   'https://item.jd.com/10066851977341.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   18.2,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '成本含摊薄3元运费',
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 815781),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 815781)),
#  (10,
#   '门后无痕挂钩不锈钢免打孔卧室门上挂衣架卫生间浴室挂衣钩厨房免钉置物架强力挂勾学生宿舍',
#   'OASISWJ',
#   '10个Z型扁头挂钩（适合房门）',
#   None,
#   None,
#   'https://item.jd.com/67872313030.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   18.51,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 38, 11, 156681),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 38, 11, 156681)),
#  (3,
#   '保温饭盒上班族便携式便当盒小学生儿童餐盒小型迷你外带早餐汤杯 ',
#   '沃德百惠（WORTHBUY）',
#   '汤杯-600ML ',
#   None,
#   None,
#   'https://item.jd.com/10065289855546.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Joyce',
#   'bought',
#   33.17,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 16, 45, 42, 112536),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 16, 45, 42, 112536)),
#  (7,
#   '洗车粘土黏土洗车泥去粉尘铁屑火山泥汽车漆面美容去污泥E-HERO',
#   '绿田（LUTIAN）',
#   '洗车粘土（中切）',
#   None,
#   None,
#   'https://item.jd.com/100012888019.html',
#   None,
#   None,
#   'owned',
#   True,
#   True,
#   'Jeff',
#   'bought',
#   31.0,
#   'CNY',
#   datetime.date(2023, 3, 8),
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 855910),
#   'postgres',
#   datetime.datetime(2023, 4, 17, 17, 30, 20, 855910))]
